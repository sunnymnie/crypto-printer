# %% [markdown]
# # Testing

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/strat-discovery/results.csv")
# df = pd.read_csv("../data/ALGOUSDT-past.csv")

# %%
df.sort_values("sharpe", ascending=False)[:20]
# Out:
#            A         B  lookback  thres  sell_thres    sharpe   winrate  \
# 31  CTXCUSDT   WTCUSDT      4166   2.63        0.17  8.301550  0.888889
# 32   BTSUSDT   WANUSDT      3666   2.63        0.25  7.240875  0.888889
# 65  CTXCUSDT  NULSUSDT      3000   1.70        0.25  7.211423  0.902778
# 35  AIONUSDT  CTXCUSDT      3333   2.33       -0.25  6.997132  0.875000
# 55  CTXCUSDT  VITEUSDT      2500   2.97       -0.08  6.545189  0.880952
# 66  HIVEUSDT   MTLUSDT      5333   2.03        0.42  5.398977  0.911765
# 11   BTSUSDT  CTXCUSDT      2500   2.63       -0.33  5.227164  0.842105
# 14   NKNUSDT   WRXUSDT      4166   3.03        0.08  5.174084  0.954545
# 56  CELRUSDT   CHZUSDT      5166   2.00        0.25  4.750475  0.931034
# 21  CTXCUSDT   WANUSDT      3833   2.03       -0.17  4.349064  0.840000
# 51  CTXCUSDT  TROYUSDT      4000   2.30        0.33  4.146762  0.878788
# 53   ICXUSDT   ZRXUSDT      2500   2.70        0.25  4.013482  0.823529
# 43   BATUSDT   TCTUSDT      5833   2.97        0.25  3.729757  0.800000
# 62  NANOUSDT   RLCUSDT      4833   2.30       -0.08  3.665926  0.904762
# 2    NKNUSDT   WINUSDT      4833   2.37        0.25  3.654492  0.884615
# 29  DREPUSDT   OGNUSDT      3166   2.30        0.33  3.352173  0.885714
# 60  ARPAUSDT  CTXCUSDT      3500   1.70        0.25  3.263795  0.807018
# 58   CVCUSDT  IOSTUSDT      4500   2.30        0.50  2.896440  0.864865
# 42   GTOUSDT   HOTUSDT      5166   3.67       -0.25  2.858551  0.846154
# 15  DREPUSDT  MITHUSDT      5166   2.30       -0.17  2.608332  0.846154
#
#     avg_winloss  trades
# 31     0.044347      36
# 32     0.023676      36
# 65     0.029115      72
# 35     0.031178      56
# 55     0.040121      42
# 66     0.048187      34
# 11     0.024529      57
# 14     0.043899      22
# 56     0.033006      29
# 21     0.033815      50
# 51     0.051017      33
# 53     0.025825      34
# 43     0.051775      15
# 62     0.032214      42
# 2      0.042982      26
# 29     0.047691      35
# 60     0.036897      57
# 58     0.034918      37
# 42     0.047182      13
# 15     0.042252      39

# %% [markdown]
# ## Very good ones
# - ARDRLSK
# - COSUSDT  TROYUSDT
# - AIONUSDT COSUSDT
#
# ## Good ones
# - COSUSDT, STPTUSDT
# - COSUSDT WTCUSDT
# - AIONUSDT NULSUSDT
# - AIONUSDT WTCUSDT
# - ALGOUSDT IOTXUSDT
# - CELRUSDT FETUSDT
# - CELRUSDT COTIUSDT
# - AIONUSDT GXSUSDT
#
# ## Can't decide
# - AIONUSDT LSKUSDT
# - ARDRUSDT COSUSDT
# - COSUSDT PERLUSDT
# - CELRUSDT TROYUSDT
#
# ## Almost  good
# - BTSUSDT NULSUSDT
# - BTSUSDT TCTUSDT
# - ARDRUSDT ONGUSDT
# - DENTUSDT KEYUSDT
# - ARDRUSDT STPTUSDT
# - DOCKUSDT STPTUSDT
# - COSUSDT IOTXUSDT
# - COCOSUSDT IOTXUSDT
# - ARPAUSDT NULSUSDT
# - ALGOUSDT ARDRUSDT
# - COCOSUSDT HBARUSDT
# - CELRUSDT ONEUSDT
# - FETUSDT PERLUSDT
# - FETUSDT ONEUSDT
#
# ## Good backup
# - COSUSDT TCTUSDT
# - ARDRUSDT XTZUSDT
# - COSUSDT HIVEUSDT
# - DUSKUSDT IOTXUSDT
# - ARDRUSDT ARPAUSDT
# - DUSKUSDT STPTUSDT
# - ARDRUSDT ICXUSDT

# %%
# - BTSUSDT NULSUSDT
# - BTSUSDT TCTUSDT
# - ARDRUSDT ONGUSDT
# - DENTUSDT KEYUSDT
# - ARDRUSDT STPTUSDT
# - DOCKUSDT STPTUSDT
# - COSUSDT IOTXUSDT
# - COCOSUSDT IOTXUSDT
# - ARPAUSDT NULSUSDT
# - ALGOUSDT ARDRUSDT
# - COCOSUSDT HBARUSDT
# - CELRUSDT ONEUSDT
# - FETUSDT PERLUSDT
- FETUSDT ONEUSDT

# %%
d
# Out:
#            A        B  lookback  thres  sell_thres    sharpe  winrate  \
# 117  FETUSDT  ONEUSDT      5666   2.37        0.25 -0.531466      0.5
#
#      avg_winloss  trades
# 117      0.05706      16

# %%
d = df[(df.A == "FETUSDT") & (df.B == "ONEUSDT")]
a = d.iloc[0].A
b = d.iloc[0].B
backtest(a, b)

# %%
forwardtest(a, b)

# %% [markdown]
# ## Strats to use
# - ARDRUSDT LSKUSDT 1.
# - COSUSDT  TROYUSDT 1.
# - AIONUSDT NULSUSDT 0.95 or GXSUSDT, WTCUSDT
# - ALGOUSDT IOTXUSDT 0.5
# - CELRUSDT COTIUSDT 0.4 or FETUSDT
# - BTSUSDT TCTUSDT 0.4
# - DOCKUSDT STPTUSDT 0.4
# - COCOSUSDT HBARUSDT 0.3

# %%
saved = 9

# %%
index = saved
saved += 1
df[index:index+1]

a = df.iloc[index].A
b = df.iloc[index].B
print(f"A: {a}, B:{b}, shape: {df.iloc[index].sharpe}")
backtest(a, b)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-301-885271286084> in <module>
#       3 df[index:index+1]
#       4
# ----> 5 a = df.iloc[index].A
#       6 b = df.iloc[index].B
#       7 print(f"A: {a}, B:{b}, shape: {df.iloc[index].sharpe}")
#
# /Volumes/Storage/Programming/crypto-printer/env/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# /Volumes/Storage/Programming/crypto-printer/env/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1564
#    1565             # validate the location
# -> 1566             self._validate_integer(key, axis)
#    1567
#    1568             return self.obj._ixs(key, axis=axis)
#
# /Volumes/Storage/Programming/crypto-printer/env/lib/python3.9/site-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    1498         len_axis = len(self.obj._get_axis(axis))
#    1499         if key >= len_axis or key < -len_axis:
# -> 1500             raise IndexError("single positional indexer is out-of-bounds")
#    1501
#    1502     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds

# %%
forwardtest(a, b)

# %%
print(df.iloc[index].A + " " + df.iloc[index].B)
# Out:
# FETUSDT ONEUSDT

# %%
from IPython.display import Image
def backtest(a, b):
    return Image(filename=f'../data/generated/backtest-graphs/{a.upper()}-{b.upper()}.png') 
def forwardtest(a, b):
    return Image(filename=f'../data/generated/forwardtest-graphs/{a.upper()}-{b.upper()}.png')

# %%
test()
