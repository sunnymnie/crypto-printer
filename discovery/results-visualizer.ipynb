# %% [markdown]
# # Testing

# %%
import pandas as pd
import numpy as np

# %%
from IPython.display import Image, display
def backtest(a, b):
    return Image(filename=f'../data/generated/backtest-graphs/{a.upper()}-{b.upper()}.png') 
def forwardtest(a, b):
    return Image(filename=f'../data/generated/forwardtest-graphs/{a.upper()}-{b.upper()}.png') 
def show(a, b):
    listOfImageNames = [f'../data/generated/backtest-graphs/{a.upper()}-{b.upper()}.png',
                        f'../data/generated/forwardtest-graphs/{a.upper()}-{b.upper()}.png']
    for imageName in listOfImageNames:
        display(Image(filename=imageName, width = 500, height = 200))

# %%
df = pd.read_csv("../data/strat-discovery/results.csv")
len(df)
# df = pd.read_csv("../data/ALGOUSDT-past.csv")
# Out:
# 178

# %%
df = df[df.trades >= 10].sort_values("sharpe", ascending=False)

# %%
df.iloc[:20]
# Out:
#             A         B  lookback  thres  sell_thres    sharpe   winrate  \
# 116   CVCUSDT   ZILUSDT      3833   4.30       -0.75  8.079960  1.000000
# 156   MTLUSDT   XRPUSDT      4833   3.70        0.00  7.387850  1.000000
# 59   NANOUSDT   XLMUSDT      4666   3.70        0.33  6.604093  0.923077
# 124  NANOUSDT   XRPUSDT      5500   3.70        0.00  6.418995  1.000000
# 1    ARDRUSDT   LSKUSDT      5666   4.00        0.08  6.352096  0.866667
# 24    ICXUSDT   ZRXUSDT      4666   3.97        0.25  5.650204  1.000000
# 77   ATOMUSDT   ZRXUSDT      5166   3.03        0.00  5.256150  0.875000
# 11    NKNUSDT   WRXUSDT      4166   3.03        0.25  5.229822  0.909091
# 67   CELRUSDT   ONGUSDT      4166   4.30       -0.08  4.774633  0.928571
# 32   HIVEUSDT   MTLUSDT      6000   3.37        0.08  4.745707  0.944444
# 46    BATUSDT  CELRUSDT      4666   3.70        0.00  4.687831  0.923077
# 14    BTTUSDT   NKNUSDT      6166   3.97       -0.58  4.442082  0.785714
# 134   BATUSDT   BTSUSDT      5500   3.37       -0.17  4.211858  0.833333
# 110   FUNUSDT   ZRXUSDT      4833   3.70       -0.42  4.143557  0.916667
# 157   BCHUSDT  NANOUSDT      3500   3.70       -0.50  4.090659  0.764706
# 52    MTLUSDT   ONGUSDT      5000   4.30        0.50  4.032522  0.923077
# 164   ADAUSDT  NANOUSDT      4500   3.37        0.25  3.984722  0.857143
# 4     NKNUSDT   WINUSDT      5500   4.30       -0.25  3.980175  0.846154
# 99    VETUSDT   XRPUSDT      5166   4.00        0.08  3.964464  0.800000
# 78    NKNUSDT   XRPUSDT      4833   4.30        0.25  3.501308  0.900000
#
#      avg_winloss  trades
# 116     0.034129      13
# 156     0.057925      13
# 59      0.031337      13
# 124     0.031012      10
# 1       0.068642      15
# 24      0.044765      10
# 77      0.056734      16
# 11      0.048734      22
# 67      0.056235      14
# 32      0.073949      18
# 46      0.039348      13
# 14      0.058762      14
# 134     0.029598      12
# 110     0.035775      12
# 157     0.031272      17
# 52      0.062581      13
# 164     0.024018      14
# 4       0.065136      13
# 99      0.032192      10
# 78      0.060119      10

# %%
start = 0

# %%
index = start
start += 1
a = df.iloc[index].A
b = df.iloc[index].B
print(f"A: {a}, B: {b}, shape: {df.iloc[index].sharpe}, index: {index}")

# index = 164 #6,12 
# a = df.loc[index].A
# b = df.loc[index].B
# print(f"A: {a}, B: {b}, shape: {df.loc[index].sharpe}, index: {index}")
show(a, b)
# Out:
# A: MTLUSDT, B: NKNUSDT, shape: 2.6404987319163578, index: 30

# %%
df1 = pd.read_csv(f"../data/generated/forwardtests/{a}-{b}-forward-test.csv").drop(["returns", "drawdowns"], axis=1)
# df1 = pd.read_csv(f"../data/generated/backtests/{a}-{b}-sharpe.csv").sort_values("sharpe", ascending=False, ignore_index=True).drop(["returns", "drawdowns"], axis=1)
# df1 = pd.read_csv(f"../data/generated/backtests/{a}-{b}-sharpe-narrowed.csv").sort_values("sharpe", ascending=False).drop(["returns", "drawdowns"], axis=1)
df1
# Out:
#     lookback  thres  sell_thres     mxdd    sharpe  dd_filtered   winrate  \
# 0       3000   2.67       -0.17   924600  2.640499        False  0.756757
# 1       3000   2.97       -0.17   877680  2.374651        False  0.750000
# 2       3500   2.97       -0.42  1327200  2.062427        False  0.708333
# 3       3000   2.67       -0.42  1209360  1.962453        False  0.763158
# 4       3000   2.97       -0.42   925440  1.906660        False  0.724138
# 5       3500   2.67       -0.42  1503420  1.610447        False  0.735294
# 6       3500   2.37       -0.42  2475720  1.605331        False  0.780488
# 7       3000   2.37       -0.17  2725020  1.476870        False  0.756098
# 8       2500   2.97       -0.17   925440  1.404140        False  0.696970
# 9       3500   2.37       -0.17  3452940  1.009289        False  0.743590
# 10      3500   2.67       -0.17  3528360  0.940938        False  0.718750
# 11      2500   2.37       -0.17  2752500  0.769713        False  0.687500
# 12      3500   2.97       -0.17  3659820  0.741508        False  0.695652
# 13      3000   2.37       -0.42  3675360  0.669911        False  0.738095
# 14      2500   2.67       -0.17  2723040  0.575123        False  0.675000
# 15      2500   2.97       -0.42  2543940  0.410162        False  0.666667
# 16      3000   2.67        0.08  4194180  0.340787        False  0.656250
# 17      2500   2.37        0.08  3592440  0.337618        False  0.666667
# 18      2500   2.97        0.08  3652620  0.329507        False  0.677419
# 19      3500   2.97        0.08  4649400  0.226051        False  0.550000
# 20      2500   2.67        0.08  3592440  0.217608        False  0.710526
# 21      3000   2.97        0.08  4649220  0.118977        False  0.600000
# 22      3500   2.67        0.08  4867200  0.118793        False  0.615385
# 23      3000   2.37        0.08  4867200  0.107815        False  0.685714
# 24      3500   2.37        0.08  4867200  0.065072        False  0.645161
# 25      2500   2.37       -0.42  3717240  0.014120        False  0.673469
# 26      2500   2.67       -0.42  3808920 -0.363166        False  0.675000
#
#     avg_winloss  trades
# 0      0.037825      37
# 1      0.038777      28
# 2      0.043252      24
# 3      0.030930      38
# 4      0.034229      29
# 5      0.035879      34
# 6      0.029928      41
# 7      0.031827      41
# 8      0.031423      33
# 9      0.037435      39
# 10     0.043770      32
# 11     0.031359      48
# 12     0.051038      23
# 13     0.027091      42
# 14     0.028519      40
# 15     0.028824      33
# 16     0.044226      32
# 17     0.034525      45
# 18     0.035410      31
# 19     0.063553      20
# 20     0.030804      38
# 21     0.047841      25
# 22     0.048705      26
# 23     0.038634      35
# 24     0.040813      31
# 25     0.028507      49
# 26     0.024579      40

# %% [markdown]
# ## Very good ones
# - ARDRLSK
# - COSUSDT  TROYUSDT
# - AIONUSDT COSUSDT
#
# ## Good ones
# - COSUSDT, STPTUSDT
# - COSUSDT WTCUSDT
# - AIONUSDT NULSUSDT
# - AIONUSDT WTCUSDT
# - ALGOUSDT IOTXUSDT
# - CELRUSDT FETUSDT
# - CELRUSDT COTIUSDT
# - AIONUSDT GXSUSDT
#
# ## Can't decide
# - AIONUSDT LSKUSDT
# - ARDRUSDT COSUSDT
# - COSUSDT PERLUSDT
# - CELRUSDT TROYUSDT
#
# ## Almost  good
# - BTSUSDT NULSUSDT
# - BTSUSDT TCTUSDT
# - ARDRUSDT ONGUSDT
# - DENTUSDT KEYUSDT
# - ARDRUSDT STPTUSDT
# - DOCKUSDT STPTUSDT
# - COSUSDT IOTXUSDT
# - COCOSUSDT IOTXUSDT
# - ARPAUSDT NULSUSDT
# - ALGOUSDT ARDRUSDT
# - COCOSUSDT HBARUSDT
# - CELRUSDT ONEUSDT
# - FETUSDT PERLUSDT
# - FETUSDT ONEUSDT
#
# ## Good backup
# - COSUSDT TCTUSDT
# - ARDRUSDT XTZUSDT
# - COSUSDT HIVEUSDT
# - DUSKUSDT IOTXUSDT
# - ARDRUSDT ARPAUSDT
# - DUSKUSDT STPTUSDT
# - ARDRUSDT ICXUSDT

# %%
# - BTSUSDT NULSUSDT
# - BTSUSDT TCTUSDT
# - ARDRUSDT ONGUSDT
# - DENTUSDT KEYUSDT
# - ARDRUSDT STPTUSDT
# - DOCKUSDT STPTUSDT
# - COSUSDT IOTXUSDT
# - COCOSUSDT IOTXUSDT
# - ARPAUSDT NULSUSDT
# - ALGOUSDT ARDRUSDT
# - COCOSUSDT HBARUSDT
# - CELRUSDT ONEUSDT
# - FETUSDT PERLUSDT
- FETUSDT ONEUSDT

# %%
d
# Out:
#            A        B  lookback  thres  sell_thres    sharpe  winrate  \
# 117  FETUSDT  ONEUSDT      5666   2.37        0.25 -0.531466      0.5
#
#      avg_winloss  trades
# 117      0.05706      16

# %%
d = df[(df.A == "FETUSDT") & (df.B == "ONEUSDT")]
a = d.iloc[0].A
b = d.iloc[0].B
backtest(a, b)

# %%
forwardtest(a, b)

# %% [markdown]
# ## Strats to use
# - ARDRUSDT LSKUSDT 1.
# - COSUSDT  TROYUSDT 1.
# - AIONUSDT NULSUSDT 0.95 or GXSUSDT, WTCUSDT
# - ALGOUSDT IOTXUSDT 0.5
# - CELRUSDT COTIUSDT 0.4 or FETUSDT
# - BTSUSDT TCTUSDT 0.4
# - DOCKUSDT STPTUSDT 0.4
# - COCOSUSDT HBARUSDT 0.3
#
# - ARDRUSDT (166) LSKUSDT (114)
# - COSUSDT (463) TROYUSDT (386)
# - AIONUSDT (383) NULSUSDT (479) or GXSUSDT (999+) WTCUSDT (443)
# - ALGOUSDT (45) IOTXUSDT (99)
# - CELRUSDT (168) COTIUSDT (298) or FETUSDT (142)
# - BTSUSDT (197) TCTUSDT (648)
# - DOCKUSDT (466) STPTUSDT (408)
# - COCOSUSDT (595) HBARUSDT (55)

# %%
saved = 9

# %%
index = saved
saved += 1
df[index:index+1]

a = df.iloc[index].A
b = df.iloc[index].B
print(f"A: {a}, B:{b}, shape: {df.iloc[index].sharpe}")
backtest(a, b)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-301-885271286084> in <module>
#       3 df[index:index+1]
#       4
# ----> 5 a = df.iloc[index].A
#       6 b = df.iloc[index].B
#       7 print(f"A: {a}, B:{b}, shape: {df.iloc[index].sharpe}")
#
# /Volumes/Storage/Programming/crypto-printer/env/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# /Volumes/Storage/Programming/crypto-printer/env/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1564
#    1565             # validate the location
# -> 1566             self._validate_integer(key, axis)
#    1567
#    1568             return self.obj._ixs(key, axis=axis)
#
# /Volumes/Storage/Programming/crypto-printer/env/lib/python3.9/site-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    1498         len_axis = len(self.obj._get_axis(axis))
#    1499         if key >= len_axis or key < -len_axis:
# -> 1500             raise IndexError("single positional indexer is out-of-bounds")
#    1501
#    1502     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds

# %%
forwardtest(a, b)

# %%
print(df.iloc[index].A + " " + df.iloc[index].B)
# Out:
# FETUSDT ONEUSDT

# %%
backtest("BTTUSDT", "MTLUSDT")

# %% [markdown]
# ## CMC testing
