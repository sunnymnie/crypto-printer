# %% [markdown]
# # Testing

# %%
import pandas as pd
import numpy as np

# %%
from IPython.display import Image, display
def backtest(a, b):
    return Image(filename=f'../data/generated/backtest-graphs/{a.upper()}-{b.upper()}.png') 
def forwardtest(a, b):
    return Image(filename=f'../data/generated/forwardtest-graphs/{a.upper()}-{b.upper()}.png') 
def show(a, b):
    listOfImageNames = [f'../data/generated/backtest-graphs/{a.upper()}-{b.upper()}.png',
                        f'../data/generated/forwardtest-graphs/{a.upper()}-{b.upper()}.png']
    for imageName in listOfImageNames:
        display(Image(filename=imageName, width = 500, height = 200))

# %%
df = pd.read_csv("../data/strat-discovery/results.csv")
len(df)
# df = pd.read_csv("../data/ALGOUSDT-past.csv")
# Out:
# 102

# %%
df = df.sort_values("sharpe", ascending=False)

# %%
df.iloc[:15]
# Out:
#            A         B  lookback  thres  sell_thres    sharpe   winrate  \
# 59  NANOUSDT   XLMUSDT      4666   3.70        0.33  6.604093  0.923077
# 1   ARDRUSDT   LSKUSDT      5666   4.00        0.08  6.352096  0.866667
# 24   ICXUSDT   ZRXUSDT      4666   3.97        0.25  5.650204  1.000000
# 77  ATOMUSDT   ZRXUSDT      5166   3.03        0.00  5.256150  0.875000
# 11   NKNUSDT   WRXUSDT      4166   3.03        0.25  5.229822  0.909091
# 67  CELRUSDT   ONGUSDT      4166   4.30       -0.08  4.774633  0.928571
# 32  HIVEUSDT   MTLUSDT      6000   3.37        0.08  4.745707  0.944444
# 46   BATUSDT  CELRUSDT      4666   3.70        0.00  4.687831  0.923077
# 71  NANOUSDT   XMRUSDT      5833   4.30       -0.08  4.473574  1.000000
# 14   BTTUSDT   NKNUSDT      6166   3.97       -0.58  4.442082  0.785714
# 52   MTLUSDT   ONGUSDT      5000   4.30        0.50  4.032522  0.923077
# 4    NKNUSDT   WINUSDT      5500   4.30       -0.25  3.980175  0.846154
# 99   VETUSDT   XRPUSDT      5166   4.00        0.08  3.964464  0.800000
# 78   NKNUSDT   XRPUSDT      4833   4.30        0.25  3.501308  0.900000
# 84  CELRUSDT  HBARUSDT      4166   3.97       -0.42  3.494678  0.857143
#
#     avg_winloss  trades
# 59     0.031337      13
# 1      0.068642      15
# 24     0.044765      10
# 77     0.056734      16
# 11     0.048734      22
# 67     0.056235      14
# 32     0.073949      18
# 46     0.039348      13
# 71     0.040718       5
# 14     0.058762      14
# 52     0.062581      13
# 4      0.065136      13
# 99     0.032192      10
# 78     0.060119      10
# 84     0.031787       7

# %%
start = 0

# %%
# index = start
# start += 1
# a = df.iloc[index].A
# b = df.iloc[index].B

index = 99
a = df.loc[index].A
b = df.loc[index].B
print(f"A: {a}, B:{b}, shape: {df.iloc[index].sharpe}")
show(a, b)
# Out:
# A: VETUSDT, B:XRPUSDT, shape: -1.360495233389075

# %%
df = pd.read_csv(f"../data/generated/forwardtests/{a}-{b}-forward-test.csv").drop(["returns", "drawdowns"], axis=1)
# df = pd.read_csv(f"../data/generated/backtests/{a}-{b}-sharpe.csv").sort_values("sharpe", ascending=False, ignore_index=True).drop(["returns", "drawdowns"], axis=1)
# df = pd.read_csv(f"../data/generated/backtests/{a}-{b}-sharpe-narrowed.csv").sort_values("sharpe", ascending=False).drop(["returns", "drawdowns"], axis=1)
df
# Out:
#     lookback  thres  sell_thres     mxdd    sharpe  dd_filtered   winrate  \
# 0       3166   3.33        0.17  2410860 -0.968479        False  0.562500
# 1       3166   3.33       -0.08  2450700 -0.973530        False  0.588235
# 2       3666   3.63       -0.08  1253100 -0.989130        False  0.666667
# 3       3666   3.63        0.17  2382000 -0.997035        False  0.545455
# 4       4166   3.63       -0.08  1237800 -0.997983        False  0.636364
# 5       3666   3.33       -0.08  2393040 -1.001951        False  0.692308
# 6       3666   3.33        0.17  2382000 -1.002318        False  0.583333
# 7       3666   3.63        0.42  2375400 -1.006463        False  0.545455
# 8       3166   3.03        0.17  2410860 -1.008522        False  0.529412
# 9       3166   3.33        0.42  2382120 -1.011331        False  0.466667
# 10      3666   3.33        0.42  2375400 -1.012718        False  0.583333
# 11      3166   3.63       -0.08  2450700 -1.016845        False  0.666667
# 12      3166   3.03       -0.08  2450700 -1.019100        False  0.500000
# 13      3666   3.03       -0.08  2393040 -1.021713        False  0.562500
# 14      4166   3.63        0.17  2375220 -1.022289        False  0.500000
# 15      3666   3.03        0.17  2382000 -1.022409        False  0.533333
# 16      3166   3.63        0.17  2410860 -1.025936        False  0.545455
# 17      3666   3.03        0.42  2375400 -1.026384        False  0.533333
# 18      4166   3.33       -0.08  2376720 -1.033519        False  0.636364
# 19      3166   3.63        0.42  2382120 -1.041720        False  0.545455
# 20      4166   3.03       -0.08  2376720 -1.044307        False  0.500000
# 21      4166   3.33        0.17  2375220 -1.058493        False  0.400000
# 22      3166   3.03        0.42  2382120 -1.061236        False  0.375000
# 23      4166   3.63        0.42  2328660 -1.061380        False  0.555556
# 24      4166   3.03        0.17  2375220 -1.079414        False  0.272727
# 25      4166   3.33        0.42  2328660 -1.089336        False  0.555556
# 26      4166   3.03        0.42  2328660 -1.105891        False  0.500000
#
#     avg_winloss  trades
# 0      0.049312      16
# 1      0.044216      17
# 2      0.041155      12
# 3      0.048942      11
# 4      0.040759      11
# 5      0.037641      13
# 6      0.047217      12
# 7      0.043495      11
# 8      0.040567      17
# 9      0.045740      15
# 10     0.041993      12
# 11     0.037245      12
# 12     0.039228      18
# 13     0.038571      16
# 14     0.044648      10
# 15     0.041066      15
# 16     0.046178      11
# 17     0.038811      15
# 18     0.035044      11
# 19     0.037838      11
# 20     0.039100      12
# 21     0.046160      10
# 22     0.045223      16
# 23     0.048994       9
# 24     0.056567      11
# 25     0.040874       9
# 26     0.036572      10

# %% [markdown]
# ## Very good ones
# - ARDRLSK
# - COSUSDT  TROYUSDT
# - AIONUSDT COSUSDT
#
# ## Good ones
# - COSUSDT, STPTUSDT
# - COSUSDT WTCUSDT
# - AIONUSDT NULSUSDT
# - AIONUSDT WTCUSDT
# - ALGOUSDT IOTXUSDT
# - CELRUSDT FETUSDT
# - CELRUSDT COTIUSDT
# - AIONUSDT GXSUSDT
#
# ## Can't decide
# - AIONUSDT LSKUSDT
# - ARDRUSDT COSUSDT
# - COSUSDT PERLUSDT
# - CELRUSDT TROYUSDT
#
# ## Almost  good
# - BTSUSDT NULSUSDT
# - BTSUSDT TCTUSDT
# - ARDRUSDT ONGUSDT
# - DENTUSDT KEYUSDT
# - ARDRUSDT STPTUSDT
# - DOCKUSDT STPTUSDT
# - COSUSDT IOTXUSDT
# - COCOSUSDT IOTXUSDT
# - ARPAUSDT NULSUSDT
# - ALGOUSDT ARDRUSDT
# - COCOSUSDT HBARUSDT
# - CELRUSDT ONEUSDT
# - FETUSDT PERLUSDT
# - FETUSDT ONEUSDT
#
# ## Good backup
# - COSUSDT TCTUSDT
# - ARDRUSDT XTZUSDT
# - COSUSDT HIVEUSDT
# - DUSKUSDT IOTXUSDT
# - ARDRUSDT ARPAUSDT
# - DUSKUSDT STPTUSDT
# - ARDRUSDT ICXUSDT

# %%
# - BTSUSDT NULSUSDT
# - BTSUSDT TCTUSDT
# - ARDRUSDT ONGUSDT
# - DENTUSDT KEYUSDT
# - ARDRUSDT STPTUSDT
# - DOCKUSDT STPTUSDT
# - COSUSDT IOTXUSDT
# - COCOSUSDT IOTXUSDT
# - ARPAUSDT NULSUSDT
# - ALGOUSDT ARDRUSDT
# - COCOSUSDT HBARUSDT
# - CELRUSDT ONEUSDT
# - FETUSDT PERLUSDT
- FETUSDT ONEUSDT

# %%
d
# Out:
#            A        B  lookback  thres  sell_thres    sharpe  winrate  \
# 117  FETUSDT  ONEUSDT      5666   2.37        0.25 -0.531466      0.5
#
#      avg_winloss  trades
# 117      0.05706      16

# %%
d = df[(df.A == "FETUSDT") & (df.B == "ONEUSDT")]
a = d.iloc[0].A
b = d.iloc[0].B
backtest(a, b)

# %%
forwardtest(a, b)

# %% [markdown]
# ## Strats to use
# - ARDRUSDT LSKUSDT 1.
# - COSUSDT  TROYUSDT 1.
# - AIONUSDT NULSUSDT 0.95 or GXSUSDT, WTCUSDT
# - ALGOUSDT IOTXUSDT 0.5
# - CELRUSDT COTIUSDT 0.4 or FETUSDT
# - BTSUSDT TCTUSDT 0.4
# - DOCKUSDT STPTUSDT 0.4
# - COCOSUSDT HBARUSDT 0.3
#
# - ARDRUSDT (166) LSKUSDT (114)
# - COSUSDT (463) TROYUSDT (386)
# - AIONUSDT (383) NULSUSDT (479) or GXSUSDT (999+) WTCUSDT (443)
# - ALGOUSDT (45) IOTXUSDT (99)
# - CELRUSDT (168) COTIUSDT (298) or FETUSDT (142)
# - BTSUSDT (197) TCTUSDT (648)
# - DOCKUSDT (466) STPTUSDT (408)
# - COCOSUSDT (595) HBARUSDT (55)

# %%
saved = 9

# %%
index = saved
saved += 1
df[index:index+1]

a = df.iloc[index].A
b = df.iloc[index].B
print(f"A: {a}, B:{b}, shape: {df.iloc[index].sharpe}")
backtest(a, b)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-301-885271286084> in <module>
#       3 df[index:index+1]
#       4
# ----> 5 a = df.iloc[index].A
#       6 b = df.iloc[index].B
#       7 print(f"A: {a}, B:{b}, shape: {df.iloc[index].sharpe}")
#
# /Volumes/Storage/Programming/crypto-printer/env/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# /Volumes/Storage/Programming/crypto-printer/env/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1564
#    1565             # validate the location
# -> 1566             self._validate_integer(key, axis)
#    1567
#    1568             return self.obj._ixs(key, axis=axis)
#
# /Volumes/Storage/Programming/crypto-printer/env/lib/python3.9/site-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    1498         len_axis = len(self.obj._get_axis(axis))
#    1499         if key >= len_axis or key < -len_axis:
# -> 1500             raise IndexError("single positional indexer is out-of-bounds")
#    1501
#    1502     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds

# %%
forwardtest(a, b)

# %%
print(df.iloc[index].A + " " + df.iloc[index].B)
# Out:
# FETUSDT ONEUSDT

# %%
backtest("BTTUSDT", "MTLUSDT")

# %% [markdown]
# ## CMC testing
