# %% [markdown]
# # Testing

# %%
import pandas as pd
import numpy as np

# %%
from IPython.display import Image, display
def backtest(a, b):
    return Image(filename=f'../data/generated/backtest-graphs/{a.upper()}-{b.upper()}.png') 
def forwardtest(a, b):
    return Image(filename=f'../data/generated/forwardtest-graphs/{a.upper()}-{b.upper()}.png') 
def show(a, b):
    listOfImageNames = [f'../data/generated/backtest-graphs/{a.upper()}-{b.upper()}.png',
                        f'../data/generated/forwardtest-graphs/{a.upper()}-{b.upper()}.png']
    for imageName in listOfImageNames:
        display(Image(filename=imageName, width = 500, height = 200))

# %%
df = pd.read_csv("../data/strat-discovery/results.csv")
len(df)
# df = pd.read_csv("../data/ALGOUSDT-past.csv")
# Out:
# 103

# %%
df = df.sort_values("sharpe", ascending=False)

# %%
df.iloc[:15]
# Out:
#             A         B  lookback  thres  sell_thres    sharpe   winrate  \
# 102   CVCUSDT   FTMUSDT      3166   4.30        0.08  6.929534  1.000000
# 59   NANOUSDT   XLMUSDT      4666   3.70        0.33  6.604093  0.923077
# 1    ARDRUSDT   LSKUSDT      5666   4.00        0.08  6.352096  0.866667
# 24    ICXUSDT   ZRXUSDT      4666   3.97        0.25  5.650204  1.000000
# 77   ATOMUSDT   ZRXUSDT      5166   3.03        0.00  5.256150  0.875000
# 11    NKNUSDT   WRXUSDT      4166   3.03        0.25  5.229822  0.909091
# 67   CELRUSDT   ONGUSDT      4166   4.30       -0.08  4.774633  0.928571
# 32   HIVEUSDT   MTLUSDT      6000   3.37        0.08  4.745707  0.944444
# 46    BATUSDT  CELRUSDT      4666   3.70        0.00  4.687831  0.923077
# 71   NANOUSDT   XMRUSDT      5833   4.30       -0.08  4.473574  1.000000
# 14    BTTUSDT   NKNUSDT      6166   3.97       -0.58  4.442082  0.785714
# 52    MTLUSDT   ONGUSDT      5000   4.30        0.50  4.032522  0.923077
# 4     NKNUSDT   WINUSDT      5500   4.30       -0.25  3.980175  0.846154
# 99    VETUSDT   XRPUSDT      5166   4.00        0.08  3.964464  0.800000
# 78    NKNUSDT   XRPUSDT      4833   4.30        0.25  3.501308  0.900000
#
#      avg_winloss  trades
# 102     0.059162       8
# 59      0.031337      13
# 1       0.068642      15
# 24      0.044765      10
# 77      0.056734      16
# 11      0.048734      22
# 67      0.056235      14
# 32      0.073949      18
# 46      0.039348      13
# 71      0.040718       5
# 14      0.058762      14
# 52      0.062581      13
# 4       0.065136      13
# 99      0.032192      10
# 78      0.060119      10

# %%
start = 0

# %%
index = start
start += 1
a = df.iloc[index].A
b = df.iloc[index].B

# index = 99 #6,12 
# a = df.loc[index].A
# b = df.loc[index].B
print(f"A: {a}, B: {b}, shape: {df.iloc[index].sharpe}, index: {index}")
show(a, b)
# Out:
# A: CELRUSDT, B: ONGUSDT, shape: 4.774632667766163, index: 6

# %%
df1 = pd.read_csv(f"../data/generated/forwardtests/{a}-{b}-forward-test.csv").drop(["returns", "drawdowns"], axis=1)
# df1 = pd.read_csv(f"../data/generated/backtests/{a}-{b}-sharpe.csv").sort_values("sharpe", ascending=False, ignore_index=True).drop(["returns", "drawdowns"], axis=1)
# df1 = pd.read_csv(f"../data/generated/backtests/{a}-{b}-sharpe-narrowed.csv").sort_values("sharpe", ascending=False).drop(["returns", "drawdowns"], axis=1)
df1
# Out:
#     lookback  thres  sell_thres     mxdd    sharpe  dd_filtered   winrate  \
# 0       4833    4.3       -0.58   540660  1.825566        False  0.777778
# 1       4833    4.0       -0.58   540660  1.737421        False  0.818182
# 2       4833    4.3       -0.33   476700  1.643877        False  0.875000
# 3       4333    4.3       -0.33   534720  1.591764        False  0.750000
# 4       3833    4.3       -0.33   540660  1.539784        False  0.777778
# 5       4333    4.0       -0.33  1895460  1.534740        False  0.818182
# 6       4333    3.7       -0.33  1107960  1.237690        False  0.833333
# 7       4333    3.7       -0.58   542580  1.184676        False  0.846154
# 8       4333    4.3       -0.58   542580  1.079014        False  0.750000
# 9       4833    4.0       -0.33  2323860  1.034934        False  0.777778
# 10      4333    4.0       -0.58  1919700  1.001394        False  0.818182
# 11      3833    4.3       -0.58   541560  0.950019        False  0.777778
# 12      3833    4.0       -0.58   806880  0.939939        False  0.750000
# 13      3833    4.3       -0.08   527040  0.888211        False  0.666667
# 14      4833    3.7       -0.58   540660  0.877755        False  0.833333
# 15      3833    3.7       -0.58  1136400  0.818731        False  0.642857
# 16      3833    3.7       -0.33  1131960  0.680108        False  0.750000
# 17      4833    4.3       -0.08  1382040  0.613038        False  0.750000
# 18      4833    3.7       -0.33  2323860  0.481529        False  0.800000
# 19      4333    4.3       -0.08  1344600  0.471619        False  0.625000
# 20      3833    4.0       -0.33  2395680  0.438754        False  0.700000
# 21      3833    3.7       -0.08  1206240  0.268024        False  0.750000
# 22      4333    4.0       -0.08  3060900  0.249181        False  0.700000
# 23      4333    3.7       -0.08  1344600  0.221818        False  0.636364
# 24      4833    4.0       -0.08  3492840  0.017247        False  0.777778
# 25      3833    4.0       -0.08  3767760 -0.072054        False  0.700000
# 26      4833    3.7       -0.08  3542820 -0.511826        False  0.555556
#
#     avg_winloss  trades
# 0      0.028259       9
# 1      0.022403      11
# 2      0.029940       8
# 3      0.032727       8
# 4      0.029783       9
# 5      0.024781      11
# 6      0.022340      12
# 7      0.021075      13
# 8      0.027068       8
# 9      0.022197       9
# 10     0.020240      11
# 11     0.023344       9
# 12     0.023326      12
# 13     0.032285       9
# 14     0.017797      12
# 15     0.024044      14
# 16     0.020271      12
# 17     0.032708       8
# 18     0.018455      10
# 19     0.039658       8
# 20     0.020277      10
# 21     0.021856      12
# 22     0.027080      10
# 23     0.031240      11
# 24     0.018391       9
# 25     0.019854      10
# 26     0.019738       9

# %% [markdown]
# ## Very good ones
# - ARDRLSK
# - COSUSDT  TROYUSDT
# - AIONUSDT COSUSDT
#
# ## Good ones
# - COSUSDT, STPTUSDT
# - COSUSDT WTCUSDT
# - AIONUSDT NULSUSDT
# - AIONUSDT WTCUSDT
# - ALGOUSDT IOTXUSDT
# - CELRUSDT FETUSDT
# - CELRUSDT COTIUSDT
# - AIONUSDT GXSUSDT
#
# ## Can't decide
# - AIONUSDT LSKUSDT
# - ARDRUSDT COSUSDT
# - COSUSDT PERLUSDT
# - CELRUSDT TROYUSDT
#
# ## Almost  good
# - BTSUSDT NULSUSDT
# - BTSUSDT TCTUSDT
# - ARDRUSDT ONGUSDT
# - DENTUSDT KEYUSDT
# - ARDRUSDT STPTUSDT
# - DOCKUSDT STPTUSDT
# - COSUSDT IOTXUSDT
# - COCOSUSDT IOTXUSDT
# - ARPAUSDT NULSUSDT
# - ALGOUSDT ARDRUSDT
# - COCOSUSDT HBARUSDT
# - CELRUSDT ONEUSDT
# - FETUSDT PERLUSDT
# - FETUSDT ONEUSDT
#
# ## Good backup
# - COSUSDT TCTUSDT
# - ARDRUSDT XTZUSDT
# - COSUSDT HIVEUSDT
# - DUSKUSDT IOTXUSDT
# - ARDRUSDT ARPAUSDT
# - DUSKUSDT STPTUSDT
# - ARDRUSDT ICXUSDT

# %%
# - BTSUSDT NULSUSDT
# - BTSUSDT TCTUSDT
# - ARDRUSDT ONGUSDT
# - DENTUSDT KEYUSDT
# - ARDRUSDT STPTUSDT
# - DOCKUSDT STPTUSDT
# - COSUSDT IOTXUSDT
# - COCOSUSDT IOTXUSDT
# - ARPAUSDT NULSUSDT
# - ALGOUSDT ARDRUSDT
# - COCOSUSDT HBARUSDT
# - CELRUSDT ONEUSDT
# - FETUSDT PERLUSDT
- FETUSDT ONEUSDT

# %%
d
# Out:
#            A        B  lookback  thres  sell_thres    sharpe  winrate  \
# 117  FETUSDT  ONEUSDT      5666   2.37        0.25 -0.531466      0.5
#
#      avg_winloss  trades
# 117      0.05706      16

# %%
d = df[(df.A == "FETUSDT") & (df.B == "ONEUSDT")]
a = d.iloc[0].A
b = d.iloc[0].B
backtest(a, b)

# %%
forwardtest(a, b)

# %% [markdown]
# ## Strats to use
# - ARDRUSDT LSKUSDT 1.
# - COSUSDT  TROYUSDT 1.
# - AIONUSDT NULSUSDT 0.95 or GXSUSDT, WTCUSDT
# - ALGOUSDT IOTXUSDT 0.5
# - CELRUSDT COTIUSDT 0.4 or FETUSDT
# - BTSUSDT TCTUSDT 0.4
# - DOCKUSDT STPTUSDT 0.4
# - COCOSUSDT HBARUSDT 0.3
#
# - ARDRUSDT (166) LSKUSDT (114)
# - COSUSDT (463) TROYUSDT (386)
# - AIONUSDT (383) NULSUSDT (479) or GXSUSDT (999+) WTCUSDT (443)
# - ALGOUSDT (45) IOTXUSDT (99)
# - CELRUSDT (168) COTIUSDT (298) or FETUSDT (142)
# - BTSUSDT (197) TCTUSDT (648)
# - DOCKUSDT (466) STPTUSDT (408)
# - COCOSUSDT (595) HBARUSDT (55)

# %%
saved = 9

# %%
index = saved
saved += 1
df[index:index+1]

a = df.iloc[index].A
b = df.iloc[index].B
print(f"A: {a}, B:{b}, shape: {df.iloc[index].sharpe}")
backtest(a, b)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-301-885271286084> in <module>
#       3 df[index:index+1]
#       4
# ----> 5 a = df.iloc[index].A
#       6 b = df.iloc[index].B
#       7 print(f"A: {a}, B:{b}, shape: {df.iloc[index].sharpe}")
#
# /Volumes/Storage/Programming/crypto-printer/env/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# /Volumes/Storage/Programming/crypto-printer/env/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1564
#    1565             # validate the location
# -> 1566             self._validate_integer(key, axis)
#    1567
#    1568             return self.obj._ixs(key, axis=axis)
#
# /Volumes/Storage/Programming/crypto-printer/env/lib/python3.9/site-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    1498         len_axis = len(self.obj._get_axis(axis))
#    1499         if key >= len_axis or key < -len_axis:
# -> 1500             raise IndexError("single positional indexer is out-of-bounds")
#    1501
#    1502     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds

# %%
forwardtest(a, b)

# %%
print(df.iloc[index].A + " " + df.iloc[index].B)
# Out:
# FETUSDT ONEUSDT

# %%
backtest("BTTUSDT", "MTLUSDT")

# %% [markdown]
# ## CMC testing
